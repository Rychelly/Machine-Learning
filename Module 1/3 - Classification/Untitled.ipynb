# %%
import graphlab

# %%
products = graphlab.SFrame('amazon_baby.gl/')
# Out:
# [INFO] This non-commercial license of GraphLab Create is assigned to rychelly.g.ramos@ieee.organd will expire on September 25, 2016. For commercial licensing options, visit https://dato.com/buy/.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-9490 - Server binary: /home/rychelly/Anaconda/envs/dato-env/lib/python2.7/site-packages/graphlab/unity_server - Server log: /tmp/graphlab_server_1444626901.log
# [INFO] GraphLab Server Version: 1.6.1

# %%
products.head()
# Out:
# Columns:
# 	name	str
# 	review	str
# 	rating	float
#
# Rows: 10
#
# Data:
# +-------------------------------+-------------------------------+--------+
# |              name             |             review            | rating |
# +-------------------------------+-------------------------------+--------+
# |    Planetwise Flannel Wipes   | These flannel wipes are OK... |  3.0   |
# |     Planetwise Wipe Pouch     | it came early and was not ... |  5.0   |
# | Annas Dream Full Quilt wit... | Very soft and comfortable ... |  5.0   |
# | Stop Pacifier Sucking with... | This is a product well wor... |  5.0   |
# | Stop Pacifier Sucking with... | All of my kids have cried ... |  5.0   |
# | Stop Pacifier Sucking with... | When the Binky Fairy came ... |  5.0   |
# | A Tale of Baby's Days with... | Lovely book, it's bound ti... |  4.0   |
# | Baby Tracker&reg; - Daily ... | Perfect for new parents. W... |  5.0   |
# | Baby Tracker&reg; - Daily ... | A friend of mine pinned th... |  5.0   |
# ...

# %%
selected_words = ['awesome', 'great', 'fantastic', 'amazing', 'love', 'horrible', 'bad', 'terrible', 'awful', 'wow', 'hate']

# %%
products['word_count'] = graphlab.text_analytics.count_words(products['review'])

for word in selected_words:
    print word # display which word is being counted
    products[word] = products['word_count'].apply(lambda x: x[word] if word in x else 0)
# Out:
# awesome
# great
# fantastic
# amazing
# love
# horrible
# bad
# terrible
# awful
# wow
# hate

# %%
products.head()
# Out:
# Columns:
# 	name	str
# 	review	str
# 	rating	float
# 	word_count	dict
# 	awesome	int
# 	great	int
# 	fantastic	int
# 	amazing	int
# 	love	int
# 	horrible	int
# 	bad	int
# 	terrible	int
# 	awful	int
# 	wow	int
# 	hate	int
#
# Rows: 10
#
# Data:
# +-------------------------------+-------------------------------+--------+
# |              name             |             review            | rating |
# +-------------------------------+-------------------------------+--------+
# |    Planetwise Flannel Wipes   | These flannel wipes are OK... |  3.0   |
# |     Planetwise Wipe Pouch     | it came early and was not ... |  5.0   |
# | Annas Dream Full Quilt wit... | Very soft and comfortable ... |  5.0   |
# | Stop Pacifier Sucking with... | This is a product well wor... |  5.0   |
# | Stop Pacifier Sucking with... | All of my kids have cried ... |  5.0   |
# | Stop Pacifier Sucking with... | When the Binky Fairy came ... |  5.0   |
# ...

# %%
products['awesome'].sum()
# Out:
# 2090

# %%
products['great'].sum()
# Out:
# 45206

# %%
products['fantastic'].sum()
# Out:
# 932

# %%
products['amazing'].sum()
# Out:
# 1363

# %%
products['love'].sum()
# Out:
# 42065

# %%
products['horrible'].sum()
# Out:
# 734

# %%
products['bad'].sum()
# Out:
# 3724

# %%
products['terrible'].sum()
# Out:
# 748

# %%
products['awful'].sum()
# Out:
# 383

# %%
products['wow'].sum()
# Out:
# 144

# %%
products['hate'].sum()
# Out:
# 1220

# %%
products.head()
# Out:
# Columns:
# 	name	str
# 	review	str
# 	rating	float
# 	word_count	dict
# 	awesome	int
# 	great	int
# 	fantastic	int
# 	amazing	int
# 	love	int
# 	horrible	int
# 	bad	int
# 	terrible	int
# 	awful	int
# 	wow	int
# 	hate	int
#
# Rows: 10
#
# Data:
# +-------------------------------+-------------------------------+--------+
# |              name             |             review            | rating |
# +-------------------------------+-------------------------------+--------+
# |    Planetwise Flannel Wipes   | These flannel wipes are OK... |  3.0   |
# |     Planetwise Wipe Pouch     | it came early and was not ... |  5.0   |
# | Annas Dream Full Quilt wit... | Very soft and comfortable ... |  5.0   |
# | Stop Pacifier Sucking with... | This is a product well wor... |  5.0   |
# | Stop Pacifier Sucking with... | All of my kids have cried ... |  5.0   |
# | Stop Pacifier Sucking with... | When the Binky Fairy came ... |  5.0   |
# ...

# %%
products['sentiment'] = products['rating'] >=4

# %%
train_data,test_data = products.random_split(.8, seed=0)

# %%
selected_words_model = graphlab.logistic_classifier.create(train_data,
                                                     target='sentiment',
                                                     features=selected_words,
                                                     validation_set=test_data)
# Out:
# PROGRESS: Logistic regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 146861
# PROGRESS: Number of classes           : 2
# PROGRESS: Number of feature columns   : 11
# PROGRESS: Number of unpacked features : 11
# PROGRESS: Number of coefficients    : 12
# PROGRESS: Starting Newton Method
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+--------------+-------------------+---------------------+
# PROGRESS: | Iteration | Passes   | Elapsed Time | Training-accuracy | Validation-accuracy |
# PROGRESS: +-----------+----------+--------------+-------------------+---------------------+
# PROGRESS: | 1         | 2        | 1.516558     | 0.768182          | 0.767903            |
# PROGRESS: | 2         | 3        | 1.862358     | 0.768332          | 0.767985            |
# PROGRESS: | 3         | 4        | 2.242443     | 0.768747          | 0.767712            |
# ...

# %%
selected_words_model[‘coefficients’]
# Out:
#   File "<ipython-input-22-d8595bb092a0>", line 1
#     selected_words_model[‘coefficients’]
#                          ^
# SyntaxError: invalid syntax

# %%
selected_words_model['Coefficients']
# Out:
# [ERROR] Toolkit error: Field 'Coefficients' does not exist. Use list_fields() for a list of fields that can be queried.
# ---------------------------------------------------------------------------
# ToolkitError                              Traceback (most recent call last)
# <ipython-input-23-45e08dcbf0f7> in <module>()
# ----> 1 selected_words_model['Coefficients']
#
# /home/rychelly/Anaconda/envs/dato-env/lib/python2.7/site-packages/graphlab/toolkits/_model.pyc in __getitem__(self, key)
#     573
#     574     def __getitem__(self, key):
# --> 575         return self.get(key)
#     576
#     577     def _get_wrapper(self):
#
# /home/rychelly/Anaconda/envs/dato-env/lib/python2.7/site-packages/graphlab/toolkits/classifier/logistic_classifier.pyc in get(self, field)
#     532         _mt._get_metric_tracker().track(
#     533             'toolkit.classifier.logistic_classifier.get')
# --> 534         return super(_Classifier, self).get(field)
#     535
# ...

# %%
selected_words_model.list_fields()
# Out:
# ['class_weights',
#  'classes',
#  'coefficients',
#  'convergence_threshold',
#  'feature_rescaling',
#  'features',
#  'l1_penalty',
#  'l2_penalty',
#  'lbfgs_memory_level',
#  'max_iterations',
#  'num_classes',
#  'num_coefficients',
#  'num_examples',
#  'num_examples_per_class',
#  'num_features',
#  'num_unpacked_features',
#  'progress',
#  'solver',
#  'step_size',
#  'target',
#  'training_iterations',
#  'training_loss',
#  'training_solver_status',
#  'training_time',
#  'unpacked_features']

# %%
selected_words_model['coefficients']
# Out:
# Columns:
# 	name	str
# 	index	str
# 	class	int
# 	value	float
#
# Rows: 12
#
# Data:
# +-------------+-------+-------+-----------------+
# |     name    | index | class |      value      |
# +-------------+-------+-------+-----------------+
# | (intercept) |  None |   1   |  0.899735119511 |
# |   awesome   |  None |   1   |  1.00625649388  |
# |    great    |  None |   1   |  0.699683829426 |
# |  fantastic  |  None |   1   |  0.699443114061 |
# |   amazing   |  None |   1   |  0.892025920947 |
# |     love    |  None |   1   |  1.15720106058  |
# |   horrible  |  None |   1   |  -1.75774666269 |
# |     bad     |  None |   1   | -0.904090478755 |
# |   terrible  |  None |   1   |  -1.73568678121 |
# |    awful    |  None |   1   |  -1.43812417008 |
# +-------------+-------+-------+-----------------+
# [12 rows x 4 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
swm = selected_words_model['coefficients'].sort('value', ascending=False)

# %%
selected_words_model['coefficients'].head()
# Out:
# Columns:
# 	name	str
# 	index	str
# 	class	int
# 	value	float
#
# Rows: 10
#
# Data:
# +-------------+-------+-------+-----------------+
# |     name    | index | class |      value      |
# +-------------+-------+-------+-----------------+
# | (intercept) |  None |   1   |  0.899735119511 |
# |   awesome   |  None |   1   |  1.00625649388  |
# |    great    |  None |   1   |  0.699683829426 |
# |  fantastic  |  None |   1   |  0.699443114061 |
# |   amazing   |  None |   1   |  0.892025920947 |
# |     love    |  None |   1   |  1.15720106058  |
# |   horrible  |  None |   1   |  -1.75774666269 |
# |     bad     |  None |   1   | -0.904090478755 |
# |   terrible  |  None |   1   |  -1.73568678121 |
# |    awful    |  None |   1   |  -1.43812417008 |
# +-------------+-------+-------+-----------------+
# [10 rows x 4 columns]

# %%
swm.print_rows(num_rows=12)
# Out:
# +-------------+-------+-------+-----------------+
# |     name    | index | class |      value      |
# +-------------+-------+-------+-----------------+
# |     love    |  None |   1   |  1.15720106058  |
# |   awesome   |  None |   1   |  1.00625649388  |
# | (intercept) |  None |   1   |  0.899735119511 |
# |   amazing   |  None |   1   |  0.892025920947 |
# |    great    |  None |   1   |  0.699683829426 |
# |  fantastic  |  None |   1   |  0.699443114061 |
# |     wow     |  None |   1   |  0.324810598259 |
# |     bad     |  None |   1   | -0.904090478755 |
# |     hate    |  None |   1   |  -1.28297165251 |
# |    awful    |  None |   1   |  -1.43812417008 |
# |   terrible  |  None |   1   |  -1.73568678121 |
# |   horrible  |  None |   1   |  -1.75774666269 |
# +-------------+-------+-------+-----------------+
# [12 rows x 4 columns]

# %%
selected_words_model.evaluate(test_data, metric='roc_curve')
# Out:
# {'roc_curve': Columns:
#  	threshold	float
#  	fpr	float
#  	tpr	float
#  	p	int
#  	n	int
#
#  Rows: 1001
#
#  Data:
#  +------------------+-------------------+-----+-------+------+
#  |    threshold     |        fpr        | tpr |   p   |  n   |
#  +------------------+-------------------+-----+-------+------+
#  |       0.0        | 0.000115393491807 | 0.0 | 28008 | 8666 |
#  | 0.0010000000475  |   0.999884606508  | 1.0 | 28008 | 8666 |
#  | 0.00200000009499 |   0.999884606508  | 1.0 | 28008 | 8666 |
#  | 0.00300000002608 |   0.999769213016  | 1.0 | 28008 | 8666 |
#  | 0.00400000018999 |   0.999769213016  | 1.0 | 28008 | 8666 |
#  | 0.00499999988824 |   0.999769213016  | 1.0 | 28008 | 8666 |
#  | 0.00600000005215 |   0.999769213016  | 1.0 | 28008 | 8666 |
#  | 0.00700000021607 |   0.999769213016  | 1.0 | 28008 | 8666 |
#  | 0.00800000037998 |   0.999769213016  | 1.0 | 28008 | 8666 |
#  | 0.00899999961257 |   0.999769213016  | 1.0 | 28008 | 8666 |
# ...

# %%
selected_words_model.show(view='Evaluation')

# %%
graphlab.canvas.set_target('ipynb')

# %%
diaper_champ_reviews = products[products['name'] == 'Baby Trend Diaper Champ']

# %%
diaper_champ_reviews['predicted_sentiment'] = selected_words_model.predict(diaper_champ_reviews, output_type='probability')

# %%
diaper_champ_reviews.head()
# Out:
# Columns:
# 	name	str
# 	review	str
# 	rating	float
# 	word_count	dict
# 	awesome	int
# 	great	int
# 	fantastic	int
# 	amazing	int
# 	love	int
# 	horrible	int
# 	bad	int
# 	terrible	int
# 	awful	int
# 	wow	int
# 	hate	int
# 	sentiment	int
# 	predicted_sentiment	float
#
# Rows: 10
#
# Data:
# +-------------------------+-------------------------------+--------+
# |           name          |             review            | rating |
# +-------------------------+-------------------------------+--------+
# | Baby Trend Diaper Champ | Ok - newsflash.  Diapers a... |  4.0   |
# | Baby Trend Diaper Champ | This is a good product to ... |  3.0   |
# | Baby Trend Diaper Champ | My husband and I selected ... |  1.0   |
# | Baby Trend Diaper Champ | Excellent diaper disposal ... |  5.0   |
# | Baby Trend Diaper Champ | We love our diaper champ. ... |  5.0   |
# | Baby Trend Diaper Champ | Two girlfriends and two fa... |  5.0   |
# ...

# %%
diaper_champ_reviews = diaper_champ_reviews.sort('predicted_sentiment', ascending=False)

# %%
diaper_champ_reviews.head()
# Out:
# Columns:
# 	name	str
# 	review	str
# 	rating	float
# 	word_count	dict
# 	awesome	int
# 	great	int
# 	fantastic	int
# 	amazing	int
# 	love	int
# 	horrible	int
# 	bad	int
# 	terrible	int
# 	awful	int
# 	wow	int
# 	hate	int
# 	sentiment	int
# 	predicted_sentiment	float
#
# Rows: 10
#
# Data:
# +-------------------------+-------------------------------+--------+
# |           name          |             review            | rating |
# +-------------------------+-------------------------------+--------+
# | Baby Trend Diaper Champ | I LOVE LOVE LOVE this prod... |  4.0   |
# | Baby Trend Diaper Champ | I received my Diaper Champ... |  5.0   |
# | Baby Trend Diaper Champ | Love it, love it, love it!... |  5.0   |
# | Baby Trend Diaper Champ | Works great - no smells.  ... |  5.0   |
# | Baby Trend Diaper Champ | I did love this product fo... |  3.0   |
# | Baby Trend Diaper Champ | I love this diaper pale an... |  5.0   |
# ...
